# %%
import networkx as nx

# %%
import pandas as pd
import numpy as np

# %%
from graph_description.datasets import nx_read_attributed_graph

# %%
G, df = nx_read_attributed_graph("covid")
# Out:
# 0       1000000002
# 1       1000000003
# 2       1000000003
# 3       1000000003
# 4       1000000017
#            ...
# 1335    6100000100
# 1336    6100000103
# 1337    7000000009
# 1338    1500000050
# 1339    1500000055
# Name: from, Length: 1340, dtype: int64
# 1707 1708
# 1712

# %%
G

# %%
df
# Out:
#                sex  age          province          city        infection_case  \
# patient_id
# 0             male  30s             Seoul   Jungnang-gu       overseas inflow
# 1             male  50s             Seoul     Jongno-gu  contact with patient
# 2           female  20s             Seoul   Seongbuk-gu  contact with patient
# 3           female  50s             Seoul     Jongno-gu  contact with patient
# 4             male  20s             Seoul     Jongno-gu  contact with patient
# ...            ...  ...               ...           ...                   ...
# 1703          male  60s  Gyeongsangnam-do  Hapcheon-gun  contact with patient
# 1704        female   0s  Gyeongsangnam-do      Jinju-si       overseas inflow
# 1705          male  20s  Gyeongsangnam-do   Changwon-si                   etc
# 1706        female  20s           Jeju-do       Jeju-do       overseas inflow
# 1707          male  30s           Jeju-do       Jeju-do  contact with patient
#
#            confirmed_date     state
# patient_id
# 0              2020-01-30  released
# 1              2020-01-30  released
# 2              2020-01-31  released
# 3              2020-01-31  released
# 4              2020-01-31  released
# ...                   ...       ...
# 1703           2020-04-07  released
# 1704           2020-04-08  released
# 1705           2020-04-16  released
# 1706           2020-03-29  released
# 1707           2020-04-03  released
#
# [1708 rows x 7 columns]

# %%
#filter_min_component_size(G, df, 10)

# %%
df.dtypes
# Out:
# sex               object
# age               object
# province          object
# city              object
# infection_case    object
# confirmed_date    object
# state             object
# dtype: object

# %%
df.describe()
# Out:
#            sex   age     province         city        infection_case  \
# count     1406  1227         1708         1678                  1686
# unique       2    10           16          116                    33
# top     female   50s  Gyeonggi-do  Seongnam-si  contact with patient
# freq       793   253          731          132                  1285
#
#        confirmed_date     state
# count            1708      1708
# unique            136         3
# top        2020-02-28  isolated
# freq               53      1024

# %%
import pysubgroup as ps

target = ps.BinaryTarget ('Survived', True)
searchspace = ps.create_selectors(df, ignore=['Survived'])

# %%
from graph_description.datasets import clean_covid

# %%
df1, df2 = clean_covid()
df1
# Out:
# E:\projects\graph_description\datasets\covid\PatientInfo.csv
# E:\projects\graph_description\src\graph_description\datasets.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_out["id"] = df_out.index
#       infected_by          id
# 1      1000000002  1000000005
# 2      1000000003  1000000006
# 3      1000000003  1000000007
# 4      1000000003  1000000010
# 5      1000000017  1000000013
# ...           ...         ...
# 1342   6100000100  6100000112
# 1343   6100000103  6100000114
# 1344   7000000009  7000000011
# 1345   1500000050  5000000022
# 1346   1500000055  5000000022
#
# [1340 rows x 2 columns]

# %%
df2
# Out:
#                sex  age country          province          city  \
# patient_id
# 1000000002    male  30s   Korea             Seoul   Jungnang-gu
# 1000000003    male  50s   Korea             Seoul     Jongno-gu
# 1000000005  female  20s   Korea             Seoul   Seongbuk-gu
# 1000000006  female  50s   Korea             Seoul     Jongno-gu
# 1000000007    male  20s   Korea             Seoul     Jongno-gu
# ...            ...  ...     ...               ...           ...
# 6100000112    male  60s   Korea  Gyeongsangnam-do  Hapcheon-gun
# 6100000114  female   0s   Korea  Gyeongsangnam-do      Jinju-si
# 6100000115    male  20s   Korea  Gyeongsangnam-do   Changwon-si
# 7000000009  female  20s   Korea           Jeju-do       Jeju-do
# 7000000011    male  30s   Korea           Jeju-do       Jeju-do
#
#                   infection_case infected_by contact_number  \
# patient_id
# 1000000002       overseas inflow         NaN             31
# 1000000003  contact with patient  2002000001             17
# 1000000005  contact with patient  1000000002              2
# 1000000006  contact with patient  1000000003             43
# 1000000007  contact with patient  1000000003              0
# ...                          ...         ...            ...
# 6100000112  contact with patient  6100000100            NaN
# 6100000114       overseas inflow  6100000103            NaN
# 6100000115                   etc         NaN            NaN
# 7000000009       overseas inflow         NaN             14
# 7000000011  contact with patient  7000000009              5
#
#            symptom_onset_date confirmed_date released_date deceased_date  \
# patient_id
# 1000000002                NaN     2020-01-30    2020-03-02           NaN
# 1000000003                NaN     2020-01-30    2020-02-19           NaN
# 1000000005                NaN     2020-01-31    2020-02-24           NaN
# 1000000006                NaN     2020-01-31    2020-02-19           NaN
# 1000000007                NaN     2020-01-31    2020-02-10           NaN
# ...                       ...            ...           ...           ...
# 6100000112         2020-04-03     2020-04-07           NaN           NaN
# 6100000114         2020-04-01     2020-04-08           NaN           NaN
# 6100000115         2020-04-14     2020-04-16    2020-04-25           NaN
# 7000000009                NaN     2020-03-29    2020-04-28           NaN
# 7000000011                NaN     2020-04-03    2020-05-19           NaN
#
#                state
# patient_id
# 1000000002  released
# 1000000003  released
# 1000000005  released
# 1000000006  released
# 1000000007  released
# ...              ...
# 6100000112  released
# 6100000114  released
# 6100000115  released
# 7000000009  released
# 7000000011  released
#
# [1712 rows x 13 columns]
