# %%
from pathlib import Path
import numpy as np
import pandas as pd

from xgboost import XGBClassifier

# %%
class my_class():
    def __init__(self, d):
        self.d=d
    def __getattr__(self, key):
        return self.d[key]

# %%
from sklearn.metrics import accuracy_score
def my_accuracy(y_true, y_pred):
    if len(y_pred.shape)>1:
        true_labels = np.argmax(y_pred, axis=1)
    else:
        true_labels=y_pred

    return -accuracy_score(y_true, true_labels)

# %%
score_dict = {}

# %%
prefix = "../"

# %%
stopping_round=100
dataset = "citeseer"
wildcards = my_class({'dataset': dataset, 'group': 'planetoid', 'round': '1', 'num_train_per_class': '50', 'num_val': '500', 'num_test': 'rest', 'split_seed': '0', 'n_estimators': '5000', 'max_depth': '1', 'clf_seed': '0', 'early_stopping_rounds': f'_{stopping_round}'})

# %%
train_per_class = 20

# %%
input = [Path(prefix+f"/snakemake_base/splits/{dataset}_planetoid/{train_per_class}_500_rest_0.npz").resolve().absolute(),
         Path(prefix+f"snakemake_base/aggregated_datasets/{dataset}_planetoid_0.pkl").resolve().absolute()]

# %%
splits = np.load(input[0])
train_mask = splits["train_mask"]
val_mask = splits["val_mask"]

df  = pd.read_pickle(input[1])
train_df = df[train_mask]
#print("number_of_columns", len(df.columns))
X_train = train_df.drop("labels", axis=1)

y_train = train_df["labels"]
print(df.shape)
# Out:
# (3327, 3704)

# %%
from xgboost.callback import TrainingCallback, LearningRateScheduler

# %%
class GammaScheduler(TrainingCallback):
    def __init__(self, gamma, decay=0.9):
        self.gamma=gamma
        self.decay=decay
    def after_iteration(self, model, epoch, evals_log):
        #print(model.attributes())
        self.gamma*=self.decay
        model.set_param("min_split_loss", self.gamma)
        #print(dir(model))
        #model.gamma = model.gamma*0.95
        #print(evals_log)

class ChildWeightScheduler(TrainingCallback):
    def __init__(self, min_child_weight, timespan=10, min_size=1):
        self.min_child_weight=int(min_child_weight)
        self.timespan=timespan
        self.min_size=min_size
    def after_iteration(self, model, epoch, evals_log):
        #print(model.attributes())
        if epoch>0 and epoch % self.timespan == 0:
            self.min_child_weight=max(self.min_size, self.min_child_weight-1)
            print("new_child_weight", self.min_child_weight)
            model.set_param("min_child_weight", self.min_child_weight)

# %%
class LRScheduler(TrainingCallback):
    def __init__(self, gamma, decay=0.95, min_lr=0.03):
        self.start_gamma=gamma
        self.gamma=gamma
        self.decay=decay
        self.min_lr = min_lr
        self.min_message=True
    def after_iteration(self, model, epoch, evals_log):
        #print(model.attributes())
        new_gamma = max(self.gamma * self.decay, self.min_lr)
        if new_gamma==self.min_lr and self.min_message:
            self.min_message=False
            print("min lr reached")
        self.gamma=new_gamma
        model.set_param("learning_rate", self.gamma)
        #print(dir(model))
        #model.gamma = model.gamma*0.95
        #print(evals_log)

        
class ChildWeightSampleScheduler(TrainingCallback):
    def __init__(self, timespan=10, start_sample=0.3, sample_step=0.05, max_sample=1.0):
        self.start_sample=start_sample
        self.sample=start_sample
        self.sample_step = sample_step
        self.min_child_weight=int(max(min(self.sample*train_per_class/2.3,10),3))
        self.timespan=timespan
        self.min_size=max(int(self.sample*train_per_class/7),3)
        self.max_sample=max_sample
        
        
    def after_iteration(self, model, epoch, evals_log):
        #print(model.attributes())
        if epoch>0 and epoch % self.timespan == 0:
            new_size = max(self.min_size, self.min_child_weight-1)
            if new_size<self.min_child_weight:
                self.min_child_weight=new_size
                print("new_child_weight", self.min_child_weight)
                model.set_param("min_child_weight", self.min_child_weight)
            else:
                if self.sample==self.max_sample:
                    return
                self.sample+=self.sample_step
                new_sample = min(self.sample, self.max_sample)

                self.sample=new_sample
                print("new sample", self.sample)
                print(self.sample, train_per_class, self.sample*train_per_class)
                model.set_param("subsample", self.sample)
                #model.set_param("colsample_bylevel", self.sample)
                #model.set_param("colsample_bynode", self.sample)
                #model.set_param("colsample_bytree", self.sample)
                
                
                #self.min_child_weight=int(self.sample*train_per_class/7)
                #self.min_size=int(self.sample*train_per_class/7)
                #
                #print("new_child_weight", self.min_child_weight)
                #model.set_param("min_child_weight", self.min_child_weight)

# %%
# best at 50:
50,
  ('n_estimators', 5000),
  ('max_depth', 15),
  ('learning_rate', 0.3),
  ('objective', 'multi:softmax'),
  ('random_state', '0'),
  ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
  ('disable_default_eval_metric', 1),
  ('n_jobs', 1),
  ('early_stopping_rounds', 100),
  ('min_child_weight', 3),
  ('subsample', 0.1),
  ('colsample_bytree', 0.5),
  ('colsample_bylevel', 0.5),
  ('colsample_bynode', 0.5),
  ('callbacks',
   (<__main__.ChildWeightSampleScheduler at 0x7ff0407de8f0>,
    <__main__.LRScheduler at 0x7ff040a40940>)),
  ('start_sample', 0.1),
  ('sample', 0.9),
  ('sample_step', 0.05),
  ('min_child_weight', 3),
  ('timespan', 5),
  ('min_size', 5),
  ('max_sample', 0.9),
  ('start_gamma', 0.3),
  ('gamma', 0.01),
  ('decay', 0.97),
  ('min_lr', 0.01)): -0.628,

# best at 100
 100,
  ('n_estimators', 5000),
  ('max_depth', 10),
  ('learning_rate', 0.03),
  ('objective', 'multi:softmax'),
  ('random_state', '0'),
  ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
  ('disable_default_eval_metric', 1),
  ('n_jobs', 1),
  ('early_stopping_rounds', 150),
  ('min_child_weight', 10),
  ('subsample', 0.4),
  ('colsample_bytree', 0.4),
  ('colsample_bylevel', 0.4),
  ('colsample_bynode', 0.4),
  ('callbacks',
   (<__main__.ChildWeightSampleScheduler at 0x7ff041e6f640>,))): -0.716,
 ('citeseer',
  100,
  ('n_estimators', 5000),
  ('max_depth', 10),
  ('learning_rate', 0.03),
  ('objective', 'multi:softmax'),
  ('random_state', '0'),
  ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
  ('disable_default_eval_metric', 1),
  ('n_jobs', 1),
  ('early_stopping_rounds', 50),
  ('min_child_weight', 10),
  ('subsample', 0.4),
  ('colsample_bytree', 0.4),
  ('colsample_bylevel', 0.4),
  ('colsample_bynode', 0.4),
  ('callbacks',
   (<__main__.ChildWeightSampleScheduler at 0x7ff042f960e0>,))): -0.716,
# Out:
#   Cell In[833], line 2
#     ('max_depth', 15),
#     ^
# IndentationError: unexpected indent

# %%
val_df = df[val_mask]
X_val = val_df.drop("labels", axis=1)
y_val = val_df["labels"]
sample={10:1,20:0.5,50:0.45, 100:0.3}[train_per_class]
child_scheduler = ChildWeightSampleScheduler(timespan=5, start_sample=.45, sample_step=0.01, max_sample=0.7 )
lr_scheduler = LRScheduler(0.2, 0.99, min_lr=0.05)
print(child_scheduler.min_child_weight)
params = dict( 
    n_estimators=int(wildcards.n_estimators),
    max_depth=15,
    learning_rate=0.2,
    objective='multi:softmax',
    random_state=wildcards.clf_seed,
    eval_metric=my_accuracy,
    disable_default_eval_metric= 1,
    n_jobs=1,
    early_stopping_rounds=int(wildcards.early_stopping_rounds[1:]),
    min_child_weight=child_scheduler.min_child_weight,
#    tree_method="approx",
#    gamma=1,
    subsample=sample,
    colsample_bytree = 0.5,
    #max_delta_step=0.2
#    reg_lambda = 50,
#    reg_alpha = 1.5,
    colsample_bylevel = 0.5,
    colsample_bynode = 0.5,
    callbacks = (child_scheduler,lr_scheduler)
)
bst = XGBClassifier(**params

)
result = bst.fit(X_train,
        y_train,
        eval_set=[(X_train, y_train), (X_val, y_val)],
        verbose=True)
#print(dir(bst))
#print("EVAL RESULTS", bst.evals_result())
train_score = my_accuracy(y_train, bst.predict(X_train))
print("Best_iteration", bst.best_iteration, f"delta={bst.best_score-train_score:.3}", "best_score", bst.best_score)
score_dict[(dataset, train_per_class,)+tuple(params.items())+tuple(child_scheduler.__dict__.items())+tuple(lr_scheduler.__dict__.items())]=(bst.best_score)
# Out:
# 3
# [0]	validation_0-my_accuracy:-0.20000	validation_1-my_accuracy:-0.09000
# [1]	validation_0-my_accuracy:-0.23333	validation_1-my_accuracy:-0.10400
# [2]	validation_0-my_accuracy:-0.26667	validation_1-my_accuracy:-0.10800
# [3]	validation_0-my_accuracy:-0.26667	validation_1-my_accuracy:-0.19200
# [4]	validation_0-my_accuracy:-0.17500	validation_1-my_accuracy:-0.15600
# new sample 0.46
# 0.46 20 9.200000000000001
# [5]	validation_0-my_accuracy:-0.20833	validation_1-my_accuracy:-0.16000
# [6]	validation_0-my_accuracy:-0.29167	validation_1-my_accuracy:-0.16200
# [7]	validation_0-my_accuracy:-0.32500	validation_1-my_accuracy:-0.17200
# [8]	validation_0-my_accuracy:-0.33333	validation_1-my_accuracy:-0.24400
# [9]	validation_0-my_accuracy:-0.42500	validation_1-my_accuracy:-0.38400
# new sample 0.47000000000000003
# 0.47000000000000003 20 9.4
# [10]	validation_0-my_accuracy:-0.35833	validation_1-my_accuracy:-0.32800
# [11]	validation_0-my_accuracy:-0.45000	validation_1-my_accuracy:-0.37200
# [12]	validation_0-my_accuracy:-0.49167	validation_1-my_accuracy:-0.36400
# [13]	validation_0-my_accuracy:-0.52500	validation_1-my_accuracy:-0.38200
# [14]	validation_0-my_accuracy:-0.51667	validation_1-my_accuracy:-0.38600
# new sample 0.48000000000000004
# 0.48000000000000004 20 9.600000000000001
# [15]	validation_0-my_accuracy:-0.47500	validation_1-my_accuracy:-0.37400
# [16]	validation_0-my_accuracy:-0.52500	validation_1-my_accuracy:-0.36400
# [17]	validation_0-my_accuracy:-0.49167	validation_1-my_accuracy:-0.37000
# [18]	validation_0-my_accuracy:-0.50833	validation_1-my_accuracy:-0.38600
# [19]	validation_0-my_accuracy:-0.51667	validation_1-my_accuracy:-0.38400
# new sample 0.49000000000000005
# 0.49000000000000005 20 9.8
# [20]	validation_0-my_accuracy:-0.50000	validation_1-my_accuracy:-0.38600
# [21]	validation_0-my_accuracy:-0.50833	validation_1-my_accuracy:-0.39200
# [22]	validation_0-my_accuracy:-0.51667	validation_1-my_accuracy:-0.39800
# [23]	validation_0-my_accuracy:-0.49167	validation_1-my_accuracy:-0.39000
# [24]	validation_0-my_accuracy:-0.50833	validation_1-my_accuracy:-0.38600
# new sample 0.5
# 0.5 20 10.0
# [25]	validation_0-my_accuracy:-0.50833	validation_1-my_accuracy:-0.37400
# [26]	validation_0-my_accuracy:-0.53333	validation_1-my_accuracy:-0.39800
# [27]	validation_0-my_accuracy:-0.54167	validation_1-my_accuracy:-0.39200
# [28]	validation_0-my_accuracy:-0.58333	validation_1-my_accuracy:-0.41000
# [29]	validation_0-my_accuracy:-0.57500	validation_1-my_accuracy:-0.41000
# new sample 0.51
# 0.51 20 10.2
# [30]	validation_0-my_accuracy:-0.58333	validation_1-my_accuracy:-0.41200
# [31]	validation_0-my_accuracy:-0.55000	validation_1-my_accuracy:-0.41200
# [32]	validation_0-my_accuracy:-0.57500	validation_1-my_accuracy:-0.41400
# [33]	validation_0-my_accuracy:-0.57500	validation_1-my_accuracy:-0.41800
# [34]	validation_0-my_accuracy:-0.57500	validation_1-my_accuracy:-0.42800
# new sample 0.52
# 0.52 20 10.4
# [35]	validation_0-my_accuracy:-0.58333	validation_1-my_accuracy:-0.41800
# [36]	validation_0-my_accuracy:-0.57500	validation_1-my_accuracy:-0.43000
# [37]	validation_0-my_accuracy:-0.58333	validation_1-my_accuracy:-0.42200
# [38]	validation_0-my_accuracy:-0.57500	validation_1-my_accuracy:-0.42800
# [39]	validation_0-my_accuracy:-0.55833	validation_1-my_accuracy:-0.44000
# new sample 0.53
# 0.53 20 10.600000000000001
# [40]	validation_0-my_accuracy:-0.56667	validation_1-my_accuracy:-0.44400
# [41]	validation_0-my_accuracy:-0.55833	validation_1-my_accuracy:-0.44400
# [42]	validation_0-my_accuracy:-0.57500	validation_1-my_accuracy:-0.44800
# [43]	validation_0-my_accuracy:-0.56667	validation_1-my_accuracy:-0.44800
# [44]	validation_0-my_accuracy:-0.58333	validation_1-my_accuracy:-0.44800
# new sample 0.54
# 0.54 20 10.8
# [45]	validation_0-my_accuracy:-0.58333	validation_1-my_accuracy:-0.44400
# [46]	validation_0-my_accuracy:-0.60000	validation_1-my_accuracy:-0.43800
# [47]	validation_0-my_accuracy:-0.59167	validation_1-my_accuracy:-0.43200
# [48]	validation_0-my_accuracy:-0.60833	validation_1-my_accuracy:-0.42800
# [49]	validation_0-my_accuracy:-0.59167	validation_1-my_accuracy:-0.43200
# new sample 0.55
# 0.55 20 11.0
# [50]	validation_0-my_accuracy:-0.60000	validation_1-my_accuracy:-0.43600
# [51]	validation_0-my_accuracy:-0.60000	validation_1-my_accuracy:-0.43200
# [52]	validation_0-my_accuracy:-0.60000	validation_1-my_accuracy:-0.43400
# [53]	validation_0-my_accuracy:-0.60000	validation_1-my_accuracy:-0.44000
# [54]	validation_0-my_accuracy:-0.61667	validation_1-my_accuracy:-0.44200
# new sample 0.56
# 0.56 20 11.200000000000001
# [55]	validation_0-my_accuracy:-0.60833	validation_1-my_accuracy:-0.44200
# [56]	validation_0-my_accuracy:-0.60833	validation_1-my_accuracy:-0.44000
# [57]	validation_0-my_accuracy:-0.60833	validation_1-my_accuracy:-0.44000
# [58]	validation_0-my_accuracy:-0.60000	validation_1-my_accuracy:-0.44400
# [59]	validation_0-my_accuracy:-0.63333	validation_1-my_accuracy:-0.44600
# new sample 0.5700000000000001
# 0.5700000000000001 20 11.400000000000002
# [60]	validation_0-my_accuracy:-0.61667	validation_1-my_accuracy:-0.45600
# [61]	validation_0-my_accuracy:-0.62500	validation_1-my_accuracy:-0.45200
# [62]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.44600
# [63]	validation_0-my_accuracy:-0.63333	validation_1-my_accuracy:-0.45200
# [64]	validation_0-my_accuracy:-0.62500	validation_1-my_accuracy:-0.45400
# new sample 0.5800000000000001
# 0.5800000000000001 20 11.600000000000001
# [65]	validation_0-my_accuracy:-0.63333	validation_1-my_accuracy:-0.45800
# [66]	validation_0-my_accuracy:-0.63333	validation_1-my_accuracy:-0.45200
# [67]	validation_0-my_accuracy:-0.63333	validation_1-my_accuracy:-0.45400
# [68]	validation_0-my_accuracy:-0.63333	validation_1-my_accuracy:-0.45400
# [69]	validation_0-my_accuracy:-0.62500	validation_1-my_accuracy:-0.45400
# new sample 0.5900000000000001
# 0.5900000000000001 20 11.8
# [70]	validation_0-my_accuracy:-0.62500	validation_1-my_accuracy:-0.45400
# [71]	validation_0-my_accuracy:-0.62500	validation_1-my_accuracy:-0.44600
# [72]	validation_0-my_accuracy:-0.63333	validation_1-my_accuracy:-0.44600
# [73]	validation_0-my_accuracy:-0.63333	validation_1-my_accuracy:-0.44400
# [74]	validation_0-my_accuracy:-0.63333	validation_1-my_accuracy:-0.44800
# new sample 0.6000000000000001
# 0.6000000000000001 20 12.000000000000002
# [75]	validation_0-my_accuracy:-0.63333	validation_1-my_accuracy:-0.44600
# [76]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.44600
# [77]	validation_0-my_accuracy:-0.63333	validation_1-my_accuracy:-0.44400
# [78]	validation_0-my_accuracy:-0.63333	validation_1-my_accuracy:-0.44400
# [79]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.44600
# new sample 0.6100000000000001
# 0.6100000000000001 20 12.200000000000003
# [80]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.44200
# [81]	validation_0-my_accuracy:-0.63333	validation_1-my_accuracy:-0.44600
# [82]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.45800
# [83]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.45600
# [84]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.45800
# new sample 0.6200000000000001
# 0.6200000000000001 20 12.400000000000002
# [85]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.45600
# [86]	validation_0-my_accuracy:-0.62500	validation_1-my_accuracy:-0.45600
# [87]	validation_0-my_accuracy:-0.63333	validation_1-my_accuracy:-0.45800
# [88]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.45600
# [89]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.45200
# new sample 0.6300000000000001
# 0.6300000000000001 20 12.600000000000001
# [90]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.45600
# [91]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.45000
# [92]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.45400
# [93]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.45400
# [94]	validation_0-my_accuracy:-0.63333	validation_1-my_accuracy:-0.46600
# new sample 0.6400000000000001
# 0.6400000000000001 20 12.800000000000002
# [95]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.46000
# [96]	validation_0-my_accuracy:-0.63333	validation_1-my_accuracy:-0.46000
# [97]	validation_0-my_accuracy:-0.63333	validation_1-my_accuracy:-0.46200
# [98]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.46200
# [99]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.46200
# new sample 0.6500000000000001
# 0.6500000000000001 20 13.000000000000004
# [100]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.46000
# [101]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.46000
# [102]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.46400
# [103]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.46600
# [104]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.47000
# new sample 0.6600000000000001
# 0.6600000000000001 20 13.200000000000003
# [105]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.47400
# [106]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.47400
# [107]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.47400
# [108]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.47400
# [109]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.47000
# new sample 0.6700000000000002
# 0.6700000000000002 20 13.400000000000002
# [110]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.47200
# [111]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.47200
# [112]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.47000
# [113]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.46600
# [114]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.46800
# new sample 0.6800000000000002
# 0.6800000000000002 20 13.600000000000003
# [115]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.46600
# [116]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.47000
# [117]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.47000
# [118]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.48000
# [119]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.48200
# new sample 0.6900000000000002
# 0.6900000000000002 20 13.800000000000004
# [120]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.47800
# [121]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.47800
# [122]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.48600
# [123]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.48600
# [124]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.48600
# new sample 0.7
# 0.7 20 14.0
# [125]	validation_0-my_accuracy:-0.63333	validation_1-my_accuracy:-0.48400
# [126]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.48200
# [127]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.48800
# [128]	validation_0-my_accuracy:-0.63333	validation_1-my_accuracy:-0.48600
# [129]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.49000
# [130]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.48800
# [131]	validation_0-my_accuracy:-0.63333	validation_1-my_accuracy:-0.48400
# [132]	validation_0-my_accuracy:-0.62500	validation_1-my_accuracy:-0.49400
# [133]	validation_0-my_accuracy:-0.61667	validation_1-my_accuracy:-0.49600
# [134]	validation_0-my_accuracy:-0.61667	validation_1-my_accuracy:-0.49600
# [135]	validation_0-my_accuracy:-0.62500	validation_1-my_accuracy:-0.49000
# [136]	validation_0-my_accuracy:-0.62500	validation_1-my_accuracy:-0.49000
# min lr reached
# [137]	validation_0-my_accuracy:-0.62500	validation_1-my_accuracy:-0.49000
# [138]	validation_0-my_accuracy:-0.62500	validation_1-my_accuracy:-0.49400
# [139]	validation_0-my_accuracy:-0.62500	validation_1-my_accuracy:-0.49400
# [140]	validation_0-my_accuracy:-0.62500	validation_1-my_accuracy:-0.49000
# [141]	validation_0-my_accuracy:-0.62500	validation_1-my_accuracy:-0.49000
# [142]	validation_0-my_accuracy:-0.62500	validation_1-my_accuracy:-0.48800
# [143]	validation_0-my_accuracy:-0.63333	validation_1-my_accuracy:-0.49000
# [144]	validation_0-my_accuracy:-0.63333	validation_1-my_accuracy:-0.49400
# [145]	validation_0-my_accuracy:-0.62500	validation_1-my_accuracy:-0.49600
# [146]	validation_0-my_accuracy:-0.63333	validation_1-my_accuracy:-0.49200
# [147]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.49400
# [148]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.50000
# [149]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.50200
# [150]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.50400
# [151]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.50200
# [152]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50600
# [153]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.50200
# [154]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.50000
# [155]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.50200
# [156]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.50000
# [157]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.49800
# [158]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.49400
# [159]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.50000
# [160]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.49600
# [161]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.49800
# [162]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.49600
# [163]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.50200
# [164]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.49800
# [165]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.49600
# [166]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.49400
# [167]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.49800
# [168]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.49200
# [169]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.50600
# [170]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50000
# [171]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50000
# [172]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50200
# [173]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.50000
# [174]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.49600
# [175]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.50000
# [176]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.50000
# [177]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.50200
# [178]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.50600
# [179]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.50000
# [180]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.50200
# [181]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.50400
# [182]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.50800
# [183]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.50800
# [184]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.50600
# [185]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.50400
# [186]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.50400
# [187]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.51000
# [188]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.51000
# [189]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.50800
# [190]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.51000
# [191]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.50800
# [192]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.51000
# [193]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.51000
# [194]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.50600
# [195]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.50800
# [196]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.50800
# [197]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.50600
# [198]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.50600
# [199]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.50800
# [200]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.50400
# [201]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.50800
# [202]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.50600
# [203]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.51000
# [204]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.51400
# [205]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.50600
# [206]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.50400
# [207]	validation_0-my_accuracy:-0.64167	validation_1-my_accuracy:-0.50600
# [208]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.51000
# [209]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.50600
# [210]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.50800
# [211]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.50600
# [212]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.50600
# [213]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.50800
# [214]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.51000
# [215]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.50800
# [216]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.50800
# [217]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.50600
# [218]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.50200
# [219]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.50400
# [220]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.50400
# [221]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.50600
# [222]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.51000
# [223]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.50600
# [224]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.50800
# [225]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.50600
# [226]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.50200
# [227]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.50200
# [228]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.50200
# [229]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.50200
# [230]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.50400
# [231]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.50200
# [232]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.50000
# [233]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.50000
# [234]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.50200
# [235]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.50600
# [236]	validation_0-my_accuracy:-0.65000	validation_1-my_accuracy:-0.50600
# [237]	validation_0-my_accuracy:-0.65833	validation_1-my_accuracy:-0.50400
# [238]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50200
# [239]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50000
# [240]	validation_0-my_accuracy:-0.67500	validation_1-my_accuracy:-0.49800
# [241]	validation_0-my_accuracy:-0.67500	validation_1-my_accuracy:-0.49800
# [242]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50200
# [243]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50000
# [244]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50400
# [245]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50400
# [246]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50400
# [247]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50400
# [248]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50200
# [249]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50400
# [250]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50200
# [251]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50200
# [252]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50400
# [253]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50000
# [254]	validation_0-my_accuracy:-0.67500	validation_1-my_accuracy:-0.50200
# [255]	validation_0-my_accuracy:-0.67500	validation_1-my_accuracy:-0.50600
# [256]	validation_0-my_accuracy:-0.67500	validation_1-my_accuracy:-0.50200
# [257]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50400
# [258]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50600
# [259]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50200
# [260]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50200
# [261]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50000
# [262]	validation_0-my_accuracy:-0.67500	validation_1-my_accuracy:-0.49800
# [263]	validation_0-my_accuracy:-0.67500	validation_1-my_accuracy:-0.49800
# [264]	validation_0-my_accuracy:-0.67500	validation_1-my_accuracy:-0.50000
# [265]	validation_0-my_accuracy:-0.67500	validation_1-my_accuracy:-0.49800
# [266]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50000
# [267]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50000
# [268]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.49800
# [269]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.49600
# [270]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.49800
# [271]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.49800
# [272]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.49800
# [273]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50200
# [274]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.49800
# [275]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50200
# [276]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50200
# [277]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50200
# [278]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50200
# [279]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50200
# [280]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50200
# [281]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50200
# [282]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50200
# [283]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.49800
# [284]	validation_0-my_accuracy:-0.67500	validation_1-my_accuracy:-0.49600
# [285]	validation_0-my_accuracy:-0.67500	validation_1-my_accuracy:-0.49600
# [286]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.49800
# [287]	validation_0-my_accuracy:-0.67500	validation_1-my_accuracy:-0.50000
# [288]	validation_0-my_accuracy:-0.67500	validation_1-my_accuracy:-0.50200
# [289]	validation_0-my_accuracy:-0.67500	validation_1-my_accuracy:-0.50200
# [290]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50200
# [291]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50000
# [292]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50000
# [293]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.49800
# [294]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50400
# [295]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50000
# [296]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50000
# [297]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.50000
# [298]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.49800
# [299]	validation_0-my_accuracy:-0.66667	validation_1-my_accuracy:-0.49800
# [300]	validation_0-my_accuracy:-0.67500	validation_1-my_accuracy:-0.50200
# [301]	validation_0-my_accuracy:-0.67500	validation_1-my_accuracy:-0.50200
# [302]	validation_0-my_accuracy:-0.67500	validation_1-my_accuracy:-0.50200
# [303]	validation_0-my_accuracy:-0.67500	validation_1-my_accuracy:-0.50400
# Best_iteration 204 delta=0.144 best_score -0.514

# %%
child_scheduler.__dict__
# Out:
# {'start_sample': 0.45,
#  'sample': 0.51,
#  'sample_step': 0.01,
#  'min_child_weight': 3,
#  'timespan': 5,
#  'min_size': 3,
#  'max_sample': 0.7}

# %%
print(dataset, train_per_class)
# Out:
# citeseer 50

# %%
0.98**200
# Out:
# 0.0175879466057215

# %%
score_dict
# Out:
# {(20,
#   ('n_estimators', 5000),
#   ('max_depth', 1),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 2),
#   ('gamma', 2),
#   ('colsample_bytree', 0.5),
#   ('reg_lambda', 5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.352,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 1),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 2),
#   ('gamma', 2),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('reg_lambda', 5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.286,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 1),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 2),
#   ('gamma', 2),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('reg_lambda', 5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.324,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 1),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 2),
#   ('gamma', 2),
#   ('colsample_bytree', 0.5),
#   ('reg_lambda', 5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.276,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 1),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 5),
#   ('gamma', 2),
#   ('colsample_bytree', 0.5),
#   ('reg_lambda', 5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.28,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 1),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 5),
#   ('gamma', 2),
#   ('colsample_bytree', 0.5),
#   ('reg_lambda', 5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.392,
#  (100,
#   ('n_estimators', 5000),
#   ('max_depth', 1),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 5),
#   ('gamma', 2),
#   ('colsample_bytree', 0.5),
#   ('reg_lambda', 5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.196,
#  (100,
#   ('n_estimators', 5000),
#   ('max_depth', 1),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 5),
#   ('gamma', 3),
#   ('colsample_bytree', 0.5),
#   ('reg_lambda', 5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.192,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 1),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 5),
#   ('gamma', 3),
#   ('colsample_bytree', 0.5),
#   ('reg_lambda', 5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.404,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 1),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 5),
#   ('gamma', 2),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('reg_lambda', 5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.364,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 1),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 5),
#   ('gamma', 2),
#   ('colsample_bytree', 0.5),
#   ('reg_lambda', 5)): 0.374,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 1),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 5),
#   ('gamma', 2),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.37,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 1),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 5),
#   ('gamma', 2),
#   ('colsample_bytree', 0.5),
#   ('reg_lambda', 5),
#   ('reg_alpha', 1),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.414,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 1),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 5),
#   ('gamma', 2),
#   ('colsample_bytree', 0.5),
#   ('reg_lambda', 5),
#   ('reg_alpha', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.384,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 1),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 5),
#   ('gamma', 1),
#   ('colsample_bytree', 0.5),
#   ('reg_lambda', 5),
#   ('reg_alpha', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.366,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 1),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 5),
#   ('gamma', 1),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('reg_lambda', 5),
#   ('reg_alpha', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.36,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 1),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 5),
#   ('gamma', 0.5),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('reg_lambda', 5),
#   ('reg_alpha', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.346,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 1),
#   ('learning_rate', 0.01),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 5),
#   ('gamma', 0.5),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('reg_lambda', 5),
#   ('reg_alpha', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.35,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 1),
#   ('learning_rate', 0.001),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 5),
#   ('gamma', 0.5),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('reg_lambda', 5),
#   ('reg_alpha', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.354,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 1),
#   ('learning_rate', 0.0001),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 5),
#   ('gamma', 0.5),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('reg_lambda', 5),
#   ('reg_alpha', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.354,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 2),
#   ('learning_rate', 0.01),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 5),
#   ('gamma', 0.5),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('reg_lambda', 5),
#   ('reg_alpha', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.4,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 3),
#   ('learning_rate', 0.01),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 5),
#   ('gamma', 0.5),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('reg_lambda', 5),
#   ('reg_alpha', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.398,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 3),
#   ('learning_rate', 0.01),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 5),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.39,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 3),
#   ('learning_rate', 0.01),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 1),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.272,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 3),
#   ('learning_rate', 0.01),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 2),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.318,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 3),
#   ('learning_rate', 0.05),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 1),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.272,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 3),
#   ('learning_rate', 0.05),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 1),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.25,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.05),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 1),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.254,
#  (100,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.05),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 1),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.166,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.05),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 1),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.278,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.05),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 2),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.3,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.05),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 3),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.358,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.05),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 3),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('reg_lambda', 5),
#   ('reg_alpha', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.306,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.05),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 1),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('reg_lambda', 5),
#   ('reg_alpha', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.312,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.01),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 1),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.294,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.01),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 1),
#   ('subsample', 0.4),
#   ('colsample_bytree', 0.4),
#   ('colsample_bylevel', 0.4),
#   ('colsample_bynode', 0.4)): 0.294,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.01),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 1),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.3),
#   ('colsample_bylevel', 0.3),
#   ('colsample_bynode', 0.3)): 0.306,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.01),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 1),
#   ('subsample', 0.2),
#   ('colsample_bytree', 0.2),
#   ('colsample_bylevel', 0.2),
#   ('colsample_bynode', 0.2)): 0.446,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.01),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 1),
#   ('subsample', 0.6),
#   ('colsample_bytree', 0.6),
#   ('colsample_bylevel', 0.6),
#   ('colsample_bynode', 0.6)): 0.274,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.01),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 1),
#   ('subsample', 0.7),
#   ('colsample_bytree', 0.7),
#   ('colsample_bylevel', 0.7),
#   ('colsample_bynode', 0.7)): 0.312,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.01),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 1),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('reg_lambda', 5),
#   ('reg_alpha', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.3,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.01),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 1),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('reg_lambda', 10),
#   ('reg_alpha', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.318,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.01),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 1),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('reg_lambda', 20),
#   ('reg_alpha', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.336,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.01),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 1),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('reg_lambda', 30),
#   ('reg_alpha', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.308,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.01),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 1),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('reg_lambda', 50),
#   ('reg_alpha', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.296,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.01),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 1),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('reg_lambda', 50),
#   ('reg_alpha', 1.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.31,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.01),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 1),
#   ('gamma', 0.5),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.276,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.01),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 1),
#   ('gamma', 1.5),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.308,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.01),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 1),
#   ('gamma', 10.5),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5)): 0.568,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.01),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 5),
#   ('gamma', 10.5),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks',
#    (<__main__.GammaScheduler at 0x7ff078556bf0>,
#     <__main__.ChildWeightScheduler at 0x7ff13cdb1cc0>))): 0.28,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.005),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 5),
#   ('gamma', 10.5),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks',
#    (<__main__.GammaScheduler at 0x7ff080d65bd0>,
#     <__main__.ChildWeightScheduler at 0x7ff043b68640>))): 0.286,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.005),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 5),
#   ('gamma', 10.5),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks',
#    (<__main__.GammaScheduler at 0x7ff080d664d0>,
#     <__main__.ChildWeightScheduler at 0x7ff043f41cf0>,
#     <__main__.LRScheduler at 0x7ff043f42230>))): 0.374,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.05),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 5),
#   ('gamma', 10.5),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks',
#    (<__main__.GammaScheduler at 0x7ff13d163ee0>,
#     <__main__.ChildWeightScheduler at 0x7ff080d642e0>,
#     <__main__.LRScheduler at 0x7ff080d65330>))): 0.65,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.05),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 5),
#   ('gamma', 10.5),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks',
#    (<__main__.GammaScheduler at 0x7ff13d46fd30>,
#     <__main__.ChildWeightScheduler at 0x7ff13ce48b50>,
#     <__main__.LRScheduler at 0x7ff080d66d40>))): 0.352,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 5),
#   ('gamma', 10.5),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks',
#    (<__main__.GammaScheduler at 0x7ff080d654e0>,
#     <__main__.ChildWeightScheduler at 0x7ff078555180>))): 0.298,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 5),
#   ('gamma', 10.5),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks',
#    (<__main__.GammaScheduler at 0x7ff13d19ef80>,
#     <__main__.ChildWeightScheduler at 0x7ff078405cc0>))): 0.272,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 5),
#   ('gamma', 10.5),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.3),
#   ('colsample_bylevel', 0.3),
#   ('colsample_bynode', 0.3),
#   ('callbacks',
#    (<__main__.GammaScheduler at 0x7ff13ce81420>,
#     <__main__.ChildWeightScheduler at 0x7ff13ce57940>))): 0.286,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 100),
#   ('min_child_weight', 5),
#   ('gamma', 10.5),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.3),
#   ('colsample_bylevel', 0.3),
#   ('colsample_bynode', 0.3),
#   ('callbacks',
#    (<__main__.GammaScheduler at 0x7ff209e24550>,
#     <__main__.ChildWeightScheduler at 0x7ff043b60190>))): 0.286,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 100),
#   ('min_child_weight', 5),
#   ('gamma', 10.5),
#   ('subsample', 0.4),
#   ('colsample_bytree', 0.4),
#   ('colsample_bylevel', 0.4),
#   ('colsample_bynode', 0.4),
#   ('callbacks',
#    (<__main__.GammaScheduler at 0x7ff13ce54760>,
#     <__main__.ChildWeightScheduler at 0x7ff043b601c0>))): 0.27,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 100),
#   ('min_child_weight', 5),
#   ('subsample', 0.4),
#   ('colsample_bytree', 0.4),
#   ('colsample_bylevel', 0.4),
#   ('colsample_bynode', 0.4),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff13cd3ce80>,))): 0.31,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 100),
#   ('min_child_weight', 5),
#   ('subsample', 0.4),
#   ('colsample_bytree', 0.4),
#   ('colsample_bylevel', 0.4),
#   ('colsample_bynode', 0.4),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff043b07e50>,))): 0.28,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 100),
#   ('min_child_weight', 5),
#   ('subsample', 0.4),
#   ('colsample_bytree', 0.4),
#   ('colsample_bylevel', 0.4),
#   ('colsample_bynode', 0.4),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff043b686d0>,))): 0.622,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 100),
#   ('min_child_weight', 5),
#   ('subsample', 0.4),
#   ('colsample_bytree', 0.4),
#   ('colsample_bylevel', 0.4),
#   ('colsample_bynode', 0.4),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff209e54a30>,))): 0.278,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 100),
#   ('min_child_weight', 5),
#   ('subsample', 0.4),
#   ('colsample_bytree', 0.4),
#   ('reg_lambda', 50),
#   ('reg_alpha', 1.5),
#   ('colsample_bylevel', 0.4),
#   ('colsample_bynode', 0.4),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff080e29b40>,))): 0.29,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 100),
#   ('min_child_weight', 5),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.3),
#   ('reg_lambda', 50),
#   ('reg_alpha', 1.5),
#   ('colsample_bylevel', 0.3),
#   ('colsample_bynode', 0.3),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff13d1a2ad0>,))): 0.616,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 100),
#   ('min_child_weight', 5),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.3),
#   ('colsample_bylevel', 0.3),
#   ('colsample_bynode', 0.3),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff13d1a16f0>,))): 0.272,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 10),
#   ('min_child_weight', 5),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.3),
#   ('colsample_bylevel', 0.3),
#   ('colsample_bynode', 0.3),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff209e57580>,))): 0.614,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.3),
#   ('colsample_bylevel', 0.3),
#   ('colsample_bynode', 0.3),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff043df79a0>,))): 0.32,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.3),
#   ('colsample_bylevel', 0.3),
#   ('colsample_bynode', 0.3),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff080dfa830>,))): 0.614,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.3),
#   ('colsample_bylevel', 0.3),
#   ('colsample_bynode', 0.3),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff13d1a02e0>,))): 0.614,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.3),
#   ('colsample_bylevel', 0.3),
#   ('colsample_bynode', 0.3),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff13d1a1090>,))): 0.32,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.3),
#   ('colsample_bylevel', 0.3),
#   ('colsample_bynode', 0.3),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff13d6b7a30>,))): 0.418,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.3),
#   ('colsample_bylevel', 0.3),
#   ('colsample_bynode', 0.3),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff13d1a1150>,))): 0.568,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.3),
#   ('colsample_bylevel', 0.3),
#   ('colsample_bynode', 0.3),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff0782c4610>,))): 0.478,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.3),
#   ('colsample_bylevel', 0.3),
#   ('colsample_bynode', 0.3),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff043b74dc0>,))): 0.386,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('gamma', 10.5),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.3),
#   ('colsample_bylevel', 0.3),
#   ('colsample_bynode', 0.3),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff07850af20>,))): 0.568,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('gamma', 1),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.3),
#   ('colsample_bylevel', 0.3),
#   ('colsample_bynode', 0.3),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff13d50bc40>,))): 0.424,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softprob'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('gamma', 1),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.3),
#   ('colsample_bylevel', 0.3),
#   ('colsample_bynode', 0.3),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff209e244c0>,))): 0.424,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('gamma', 1),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.3),
#   ('colsample_bylevel', 0.3),
#   ('colsample_bynode', 0.3),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff13cdb0a90>,))): 0.424,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('gamma', 1),
#   ('subsample', 0.8),
#   ('colsample_bytree', 0.8),
#   ('colsample_bylevel', 0.8),
#   ('colsample_bynode', 0.8),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff13d4c0f70>,))): 0.316,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('gamma', 1),
#   ('subsample', 0.1),
#   ('colsample_bytree', 0.1),
#   ('colsample_bylevel', 0.1),
#   ('colsample_bynode', 0.1),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff13cd8fcd0>,))): 0.568,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('gamma', 1),
#   ('subsample', 0.2),
#   ('colsample_bytree', 0.2),
#   ('colsample_bylevel', 0.2),
#   ('colsample_bynode', 0.2),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff13db1f070>,))): 0.568,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('gamma', 1),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.3),
#   ('colsample_bylevel', 0.3),
#   ('colsample_bynode', 0.3),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff0704317b0>,))): 0.424,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.3),
#   ('colsample_bylevel', 0.3),
#   ('colsample_bynode', 0.3),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff13db1f9d0>,))): 0.386,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('subsample', 0.4),
#   ('colsample_bytree', 0.4),
#   ('colsample_bylevel', 0.4),
#   ('colsample_bynode', 0.4),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff080df8ac0>,))): 0.326,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('subsample', 0.4),
#   ('colsample_bytree', 0.4),
#   ('colsample_bylevel', 0.4),
#   ('colsample_bynode', 0.4),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff0782c4310>,))): 0.342,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff080e9ec80>,))): 0.276,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff13ccc6050>,))): 0.562,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff043b600d0>,))): 0.286,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff0785cda50>,))): 0.32,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff080d64190>,))): 0.286,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.3),
#   ('colsample_bylevel', 0.3),
#   ('colsample_bynode', 0.3),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff07859b0a0>,))): 0.32,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.3),
#   ('colsample_bylevel', 0.3),
#   ('colsample_bynode', 0.3),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff080df9390>,))): 0.568,
#  (20,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('subsample', 0.5),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff13d1a1690>,))): 0.276,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.3),
#   ('colsample_bylevel', 0.3),
#   ('colsample_bynode', 0.3),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff13d1a0670>,))): 0.32,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.3),
#   ('colsample_bylevel', 0.3),
#   ('colsample_bynode', 0.3),
#   ('callbacks', (<__main__.ChildWeightScheduler at 0x7ff043b3cee0>,))): -0.68,
#  (50,
#   ('n_estimators', 5000),
#   ('max_depth', 5),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 5),
#   ('subsample', 0.4),
# ...
#   ('colsample_bynode', 0.5),
#   ('callbacks',
#    (<__main__.ChildWeightSampleScheduler at 0x7ff04320bd90>,
#     <__main__.LRScheduler at 0x7ff04066d6c0>)),
#   ('start_sample', 0.3),
#   ('sample', 1.0),
#   ('sample_step', 0.05),
#   ('min_child_weight', 4),
#   ('timespan', 5),
#   ('min_size', 4),
#   ('max_sample', 1.0),
#   ('start_gamma', 0.03),
#   ('gamma', 0.01),
#   ('decay', 0.98),
#   ('min_lr', 0.01)): -0.63,
#  ('citeseer',
#   50,
#   ('n_estimators', 5000),
#   ('max_depth', 15),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 50),
#   ('min_child_weight', 6),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks',
#    (<__main__.ChildWeightSampleScheduler at 0x7ff042692800>,
#     <__main__.LRScheduler at 0x7ff0424a5f00>)),
#   ('start_sample', 0.3),
#   ('sample', 1.0),
#   ('sample_step', 0.05),
#   ('min_child_weight', 4),
#   ('timespan', 5),
#   ('min_size', 4),
#   ('max_sample', 1.0),
#   ('start_gamma', 0.03),
#   ('gamma', 0.01),
#   ('decay', 0.98),
#   ('min_lr', 0.01)): -0.624,
#  ('citeseer',
#   50,
#   ('n_estimators', 5000),
#   ('max_depth', 15),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 100),
#   ('min_child_weight', 6),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks',
#    (<__main__.ChildWeightSampleScheduler at 0x7ff042cdc250>,
#     <__main__.LRScheduler at 0x7ff042401210>)),
#   ('start_sample', 0.3),
#   ('sample', 1.0),
#   ('sample_step', 0.05),
#   ('min_child_weight', 4),
#   ('timespan', 5),
#   ('min_size', 4),
#   ('max_sample', 1.0),
#   ('start_gamma', 0.03),
#   ('gamma', 0.01),
#   ('decay', 0.98),
#   ('min_lr', 0.01)): -0.624,
#  ('citeseer',
#   50,
#   ('n_estimators', 5000),
#   ('max_depth', 15),
#   ('learning_rate', 0.03),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 100),
#   ('min_child_weight', 6),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks',
#    (<__main__.ChildWeightSampleScheduler at 0x7ff042737880>,
#     <__main__.LRScheduler at 0x7ff041a127d0>)),
#   ('start_sample', 0.3),
#   ('sample', 0.9),
#   ('sample_step', 0.05),
#   ('min_child_weight', 4),
#   ('timespan', 5),
#   ('min_size', 4),
#   ('max_sample', 0.9),
#   ('start_gamma', 0.03),
#   ('gamma', 0.01),
#   ('decay', 0.98),
#   ('min_lr', 0.01)): -0.628,
#  ('citeseer',
#   50,
#   ('n_estimators', 5000),
#   ('max_depth', 15),
#   ('learning_rate', 0.07),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 100),
#   ('min_child_weight', 6),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks',
#    (<__main__.ChildWeightSampleScheduler at 0x7ff042a49d20>,
#     <__main__.LRScheduler at 0x7ff042a48af0>)),
#   ('start_sample', 0.3),
#   ('sample', 0.9),
#   ('sample_step', 0.05),
#   ('min_child_weight', 4),
#   ('timespan', 5),
#   ('min_size', 4),
#   ('max_sample', 0.9),
#   ('start_gamma', 0.07),
#   ('gamma', 0.01),
#   ('decay', 0.98),
#   ('min_lr', 0.01)): -0.632,
#  ('citeseer',
#   50,
#   ('n_estimators', 5000),
#   ('max_depth', 15),
#   ('learning_rate', 0.07),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 100),
#   ('min_child_weight', 6),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks',
#    (<__main__.ChildWeightSampleScheduler at 0x7ff0417eff70>,
#     <__main__.LRScheduler at 0x7ff041024f70>)),
#   ('start_sample', 0.3),
#   ('sample', 0.9),
#   ('sample_step', 0.05),
#   ('min_child_weight', 4),
#   ('timespan', 10),
#   ('min_size', 4),
#   ('max_sample', 0.9),
#   ('start_gamma', 0.07),
#   ('gamma', 0.01),
#   ('decay', 0.98),
#   ('min_lr', 0.01)): -0.63,
#  ('citeseer',
#   50,
#   ('n_estimators', 5000),
#   ('max_depth', 15),
#   ('learning_rate', 0.07),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 100),
#   ('min_child_weight', 6),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks',
#    (<__main__.ChildWeightSampleScheduler at 0x7ff0706c04c0>,
#     <__main__.LRScheduler at 0x7ff0706c3070>)),
#   ('start_sample', 0.3),
#   ('sample', 0.9),
#   ('sample_step', 0.05),
#   ('min_child_weight', 4),
#   ('timespan', 15),
#   ('min_size', 4),
#   ('max_sample', 0.9),
#   ('start_gamma', 0.07),
#   ('gamma', 0.01),
#   ('decay', 0.98),
#   ('min_lr', 0.01)): -0.636,
#  ('citeseer',
#   50,
#   ('n_estimators', 5000),
#   ('max_depth', 15),
#   ('learning_rate', 0.07),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 100),
#   ('min_child_weight', 6),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks',
#    (<__main__.ChildWeightSampleScheduler at 0x7ff043457820>,
#     <__main__.LRScheduler at 0x7ff042209330>)),
#   ('start_sample', 0.3),
#   ('sample', 0.9),
#   ('sample_step', 0.05),
#   ('min_child_weight', 4),
#   ('timespan', 25),
#   ('min_size', 4),
#   ('max_sample', 0.9),
#   ('start_gamma', 0.07),
#   ('gamma', 0.01),
#   ('decay', 0.98),
#   ('min_lr', 0.01)): -0.626,
#  ('citeseer',
#   50,
#   ('n_estimators', 5000),
#   ('max_depth', 15),
#   ('learning_rate', 0.1),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 100),
#   ('min_child_weight', 6),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks',
#    (<__main__.ChildWeightSampleScheduler at 0x7ff041986b60>,
#     <__main__.LRScheduler at 0x7ff043457700>)),
#   ('start_sample', 0.3),
#   ('sample', 0.9),
#   ('sample_step', 0.05),
#   ('min_child_weight', 4),
#   ('timespan', 25),
#   ('min_size', 4),
#   ('max_sample', 0.9),
#   ('start_gamma', 0.1),
#   ('gamma', 0.01),
#   ('decay', 0.98),
#   ('min_lr', 0.01)): -0.64,
#  ('citeseer',
#   50,
#   ('n_estimators', 5000),
#   ('max_depth', 15),
#   ('learning_rate', 0.3),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 100),
#   ('min_child_weight', 6),
#   ('subsample', 0.3),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks',
#    (<__main__.ChildWeightSampleScheduler at 0x7ff042a21990>,
#     <__main__.LRScheduler at 0x7ff080dd91b0>)),
#   ('start_sample', 0.3),
#   ('sample', 0.9),
#   ('sample_step', 0.05),
#   ('min_child_weight', 4),
#   ('timespan', 10),
#   ('min_size', 4),
#   ('max_sample', 0.9),
#   ('start_gamma', 0.3),
#   ('gamma', 0.01),
#   ('decay', 0.97),
#   ('min_lr', 0.01)): -0.616,
#  ('citeseer',
#   50,
#   ('n_estimators', 5000),
#   ('max_depth', 15),
#   ('learning_rate', 0.3),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 100),
#   ('min_child_weight', 6),
#   ('subsample', 0.2),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks',
#    (<__main__.ChildWeightSampleScheduler at 0x7ff13d6b7250>,
#     <__main__.LRScheduler at 0x7ff07850a3b0>)),
#   ('start_sample', 0.3),
#   ('sample', 0.9),
#   ('sample_step', 0.05),
#   ('min_child_weight', 4),
#   ('timespan', 10),
#   ('min_size', 4),
#   ('max_sample', 0.9),
#   ('start_gamma', 0.3),
#   ('gamma', 0.01),
#   ('decay', 0.97),
#   ('min_lr', 0.01)): -0.624,
#  ('citeseer',
#   50,
#   ('n_estimators', 5000),
#   ('max_depth', 15),
#   ('learning_rate', 0.3),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 100),
#   ('min_child_weight', 6),
#   ('subsample', 0.1),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks',
#    (<__main__.ChildWeightSampleScheduler at 0x7ff04230aa40>,
#     <__main__.LRScheduler at 0x7ff042c23670>)),
#   ('start_sample', 0.3),
#   ('sample', 0.9),
#   ('sample_step', 0.05),
#   ('min_child_weight', 4),
#   ('timespan', 10),
#   ('min_size', 4),
#   ('max_sample', 0.9),
#   ('start_gamma', 0.3),
#   ('gamma', 0.01),
#   ('decay', 0.97),
#   ('min_lr', 0.01)): -0.636,
#  ('citeseer',
#   50,
#   ('n_estimators', 5000),
#   ('max_depth', 15),
#   ('learning_rate', 0.3),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 100),
#   ('min_child_weight', 6),
#   ('subsample', 0.1),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks',
#    (<__main__.ChildWeightSampleScheduler at 0x7ff04186a0b0>,
#     <__main__.LRScheduler at 0x7ff041869c00>)),
#   ('start_sample', 0.3),
#   ('sample', 0.9),
#   ('sample_step', 0.05),
#   ('min_child_weight', 5),
#   ('timespan', 10),
#   ('min_size', 5),
#   ('max_sample', 0.9),
#   ('start_gamma', 0.3),
#   ('gamma', 0.01),
#   ('decay', 0.97),
#   ('min_lr', 0.01)): -0.602,
#  ('citeseer',
#   50,
#   ('n_estimators', 5000),
#   ('max_depth', 15),
#   ('learning_rate', 0.3),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 100),
#   ('min_child_weight', 3),
#   ('subsample', 0.1),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks',
#    (<__main__.ChildWeightSampleScheduler at 0x7ff042b135b0>,
#     <__main__.LRScheduler at 0x7ff042cd6ec0>)),
#   ('start_sample', 0.1),
#   ('sample', 0.9),
#   ('sample_step', 0.05),
#   ('min_child_weight', 3),
#   ('timespan', 10),
#   ('min_size', 5),
#   ('max_sample', 0.9),
#   ('start_gamma', 0.3),
#   ('gamma', 0.01),
#   ('decay', 0.97),
#   ('min_lr', 0.01)): -0.624,
#  ('citeseer',
#   50,
#   ('n_estimators', 5000),
#   ('max_depth', 15),
#   ('learning_rate', 0.3),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 100),
#   ('min_child_weight', 3),
#   ('subsample', 0.1),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks',
#    (<__main__.ChildWeightSampleScheduler at 0x7ff0407de8f0>,
#     <__main__.LRScheduler at 0x7ff040a40940>)),
#   ('start_sample', 0.1),
#   ('sample', 0.9),
#   ('sample_step', 0.05),
#   ('min_child_weight', 3),
#   ('timespan', 5),
#   ('min_size', 5),
#   ('max_sample', 0.9),
#   ('start_gamma', 0.3),
#   ('gamma', 0.01),
#   ('decay', 0.97),
#   ('min_lr', 0.01)): -0.628,
#  ('citeseer',
#   50,
#   ('n_estimators', 5000),
#   ('max_depth', 15),
#   ('learning_rate', 0.3),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 100),
#   ('min_child_weight', 3),
#   ('subsample', 0.1),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks',
#    (<__main__.ChildWeightSampleScheduler at 0x7ff0428d1c60>,
#     <__main__.LRScheduler at 0x7ff041e6d780>)),
#   ('start_sample', 0.1),
#   ('sample', 0.7),
#   ('sample_step', 0.05),
#   ('min_child_weight', 3),
#   ('timespan', 5),
#   ('min_size', 5),
#   ('max_sample', 0.7),
#   ('start_gamma', 0.3),
#   ('gamma', 0.01),
#   ('decay', 0.97),
#   ('min_lr', 0.01)): -0.618,
#  ('citeseer',
#   50,
#   ('n_estimators', 5000),
#   ('max_depth', 15),
#   ('learning_rate', 0.3),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 3),
#   ('subsample', 0.1),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks',
#    (<__main__.ChildWeightSampleScheduler at 0x7ff13ce54b80>,
#     <__main__.LRScheduler at 0x7ff043b74c40>)),
#   ('start_sample', 0.1),
#   ('sample', 0.7),
#   ('sample_step', 0.05),
#   ('min_child_weight', 3),
#   ('timespan', 5),
#   ('min_size', 5),
#   ('max_sample', 0.7),
#   ('start_gamma', 0.3),
#   ('gamma', 0.01),
#   ('decay', 0.97),
#   ('min_lr', 0.01)): -0.6,
#  ('citeseer',
#   50,
#   ('n_estimators', 5000),
#   ('max_depth', 15),
#   ('learning_rate', 0.3),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 3),
#   ('subsample', 0.1),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks',
#    (<__main__.ChildWeightSampleScheduler at 0x7ff043df66e0>,
#     <__main__.LRScheduler at 0x7ff041d55a50>)),
#   ('start_sample', 0.1),
#   ('sample', 0.7),
#   ('sample_step', 0.03),
#   ('min_child_weight', 3),
#   ('timespan', 5),
#   ('min_size', 5),
#   ('max_sample', 0.7),
#   ('start_gamma', 0.3),
#   ('gamma', 0.01),
#   ('decay', 0.97),
#   ('min_lr', 0.01)): -0.582,
#  ('citeseer',
#   50,
#   ('n_estimators', 5000),
#   ('max_depth', 15),
#   ('learning_rate', 0.3),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 3),
#   ('subsample', 0.1),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks',
#    (<__main__.ChildWeightSampleScheduler at 0x7ff041117cd0>,
#     <__main__.LRScheduler at 0x7ff043457fa0>)),
#   ('start_sample', 0.1),
#   ('sample', 0.7),
#   ('sample_step', 0.03),
#   ('min_child_weight', 3),
#   ('timespan', 5),
#   ('min_size', 5),
#   ('max_sample', 0.7),
#   ('start_gamma', 0.3),
#   ('gamma', 0.01),
#   ('decay', 0.97),
#   ('min_lr', 0.01)): -0.582,
#  ('citeseer',
#   50,
#   ('n_estimators', 5000),
#   ('max_depth', 15),
#   ('learning_rate', 0.3),
#   ('objective', 'multi:softmax'),
#   ('random_state', '0'),
#   ('eval_metric', <function __main__.my_accuracy(y_true, y_pred)>),
#   ('disable_default_eval_metric', 1),
#   ('n_jobs', 1),
#   ('early_stopping_rounds', 20),
#   ('min_child_weight', 3),
#   ('subsample', 0.1),
#   ('colsample_bytree', 0.5),
#   ('colsample_bylevel', 0.5),
#   ('colsample_bynode', 0.5),
#   ('callbacks',
#    (<__main__.ChildWeightSampleScheduler at 0x7ff042b313f0>,
#     <__main__.LRScheduler at 0x7ff0437fb670>)),
#   ('start_sample', 0.1),
#   ('sample', 0.9),
#   ('sample_step', 0.05),
#   ('min_child_weight', 3),
#   ('timespan', 5),
#   ('min_size', 5),
#   ('max_sample', 0.9),
#   ('start_gamma', 0.3),
#   ('gamma', 0.013422646412104234),
#   ('decay', 0.97),
#   ('min_lr', 0.01)): -0.604}
